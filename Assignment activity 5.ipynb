# %%
# Libraries and settings needed for analysis
import pandas as pd
import seaborn as sns

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# Maximum column width to display
pd.options.display.max_colwidth = 200

# %%
# Import package.
import pandas as pd

# Read CSV file from the current working directory.
tweets = pd.read_csv('tweets.csv')

tweets.head()
print(tweets.columns)
print(tweets.shape)
tweets
# Out:
# Index(['tweet_id', 'tweet_full_text', 'tweet_entities',
#        'tweet_entities_hashtags', 'tweet_metadata', 'tweet_retweet_count',
#        'tweet_favorite_count', 'tweet_favorited', 'tweet_retweeted',
#        'tweet_lang'],
#       dtype='object')
# (1174, 10)
#                  tweet_id  \
# 0     1567629223795527681
# 1     1567582846612553728
# 2     1567582787070304256
# 3     1567582767625428992
# 4     1567582720460570625
# ...                   ...
# 1169  1567583004209332227
# 1170  1567582945342267393
# 1171  1567582936014241792
# 1172  1567582892892782592
# 1173  1567582846847533058
#
#                                                                                                                                                                                               tweet_full_text  \
# ...

# %% [markdown]
# # View the DataFrame.

# %%
# list of all the unique values in each column.
n = tweets.nunique(axis=0)
  
print("No.of.unique values in each column :\n",
      n)
# Out:
# No.of.unique values in each column :
#  tweet_id                   1174
# tweet_full_text             961
# tweet_entities              945
# tweet_entities_hashtags     710
# tweet_metadata                1
# tweet_retweet_count          47
# tweet_favorite_count         20
# tweet_favorited               1
# tweet_retweeted               1
# tweet_lang                    1
# dtype: int64

# %% [markdown]
# # Would it be useful to only look at retweeted and favourite tweet messages?

# %%
# View  and retweeted and and favorite tweet columns.
tweets_1 = tweets[['tweet_retweeted', 'tweet_retweet_count', 'tweet_favorited','tweet_favorite_count']]

# View the DataFrame.
tweets_1
# Out:
#       tweet_retweeted  tweet_retweet_count  tweet_favorited  \
# 0               False                    0            False
# 1               False                    2            False
# 2               False                   39            False
# 3               False                    5            False
# 4               False                    0            False
# ...               ...                  ...              ...
# 1169            False                    1            False
# 1170            False                    0            False
# 1171            False                    0            False
# 1172            False                    0            False
# 1173            False                    2            False
#
#       tweet_favorite_count
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 1169                     0
# ...

# %%
# Pivot the tweets DataFrame.
tweets.pivot(index='tweet_id', columns='tweet_retweeted', values='tweet_retweet_count')
# Out:
# tweet_retweeted      False
# tweet_id
# 1567574368858914816      0
# 1567574426572439552      0
# 1567574516196573184      0
# 1567574542373060608      6
# 1567574629191151621      8
# ...                    ...
# 1567655266606530566     37
# 1567655409049280513      0
# 1567655430020636672      3
# 1567655457665294337      3
# 1567655472005582851      0
#
# [1174 rows x 1 columns]

# %% [markdown]
# # we can see that just looking at retweeted and favourite tweet message is not resulting in any positive outcome.

# %% [markdown]
# # Creating a new DataFrame containing only the text.

# %%
# Using DataFrame.filter() method.
df2 = tweets.filter(['tweet_full_text'], axis=1)
df2
# Out:
#                                                                                                                                                                                               tweet_full_text
# 0     As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                                 RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                              RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# ...

# %%
mask = df2['tweet_full_text'].isin(['#'])
#display the mask
mask.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: tweet_full_text, dtype: bool

# %%
# Create boxplot with two variables.
sns.barplot(x='tweet_retweet_count', y='tweet_favorite_count', data=tweets)
# Out:
# <AxesSubplot:xlabel='tweet_retweet_count', ylabel='tweet_favorite_count'>

# %%
tweets1 = tweets_1[tweets_1['tweet_retweet_count']>=10]

ax = sns.countplot(x='tweet_retweet_count', data=tweets1)

ax.set(ylabel='Percent')

total = len(tweets1['tweet_retweet_count'])

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x()
    y = p.get_y() + p.get_height()
    ax.annotate(percentage, (x, y))

plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vf/ymq2hz2x7lnb9nnlr6_ycvfc0000gn/T/ipykernel_45699/1855098425.py in <module>
#      13     ax.annotate(percentage, (x, y))
#      14
# ---> 15 plt.xticks(rotation=90)
#      16 plt.show()
#
# NameError: name 'plt' is not defined
